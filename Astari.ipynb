# %%
import pandas as pd

# comment

# %%
fullDataSet = pd.read_csv('star_classification.csv')

# %%
colsOfInterestDataSet = fullDataSet[['u','g','r','i','z','redshift','class']]




'''
cOIDS_u = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('u')]
cOIDS_g = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('g')]
cOIDS_r = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('r')]
cOIDS_i = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('i')]
cOIDS_z = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('z')]
cOIDS_red = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('redshift')]
cOIDS_class = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('class')]
'''
# Out:
# "\ncOIDS_u = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('u')]\ncOIDS_g = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('g')]\ncOIDS_r = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('r')]\ncOIDS_i = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('i')]\ncOIDS_z = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('z')]\ncOIDS_red = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('redshift')]\ncOIDS_class = colsOfInterestDataSet[colsOfInterestDataSet.str.contains('class')]\n"

# %%
colsOfInterestDataSet.describe()
# Out:
#                    u              g              r              i  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       21.980468      20.531387      19.645762      19.084854
# std        31.769291      31.750292       1.854760       1.757895
# min     -9999.000000   -9999.000000       9.822070       9.469903
# 25%        20.352353      18.965230      18.135828      17.732285
# 50%        22.179135      21.099835      20.125290      19.405145
# 75%        23.687440      22.123767      21.044785      20.396495
# max        32.781390      31.602240      29.571860      32.141470
#
#                    z       redshift
# count  100000.000000  100000.000000
# mean       18.668810       0.576661
# std        31.728152       0.730707
# min     -9999.000000      -0.009971
# 25%        17.460677       0.054517
# 50%        19.004595       0.424173
# 75%        19.921120       0.704154
# max        29.383740       7.011245

# %%
colsOfInterestDataSet.head()
# Out:
#           u         g         r         i         z  redshift   class
# 0  23.87882  22.27530  20.39501  19.16573  18.79371  0.634794  GALAXY
# 1  24.77759  22.83188  22.58444  21.16812  21.61427  0.779136  GALAXY
# 2  25.26307  22.66389  20.60976  19.34857  18.94827  0.644195  GALAXY
# 3  22.13682  23.77656  21.61162  20.50454  19.25010  0.932346  GALAXY
# 4  19.43718  17.58028  16.49747  15.97711  15.54461  0.116123  GALAXY

# %%
colsOfInterestDataSet.tail()
# Out:
#               u         g         r         i         z  redshift   class
# 99995  22.16759  22.97586  21.90404  21.30548  20.73569  0.000000  GALAXY
# 99996  22.69118  22.38628  20.45003  19.75759  19.41526  0.404895  GALAXY
# 99997  21.16916  19.26997  18.20428  17.69034  17.35221  0.143366  GALAXY
# 99998  25.35039  21.63757  19.91386  19.07254  18.62482  0.455040  GALAXY
# 99999  22.62171  21.79745  20.60115  20.00959  19.28075  0.542944  GALAXY

# %%
cOIDS_g = colsOfInterestDataSet[colsOfInterestDataSet['class'].str.contains('GALAXY')]
cOIDS_s = colsOfInterestDataSet[colsOfInterestDataSet['class'].str.contains('STAR')]
cOIDS_q = colsOfInterestDataSet[colsOfInterestDataSet['class'].str.contains('QSO')]
cOIDS_g.describe()
# Out:
#                   u             g             r             i             z  \
# count  59445.000000  59445.000000  59445.000000  59445.000000  59445.000000
# mean      22.587379     20.906101     19.587552     18.851990     18.449156
# std        2.264355      2.107755      1.874133      1.689809      1.656302
# min       13.897990     12.679020     11.746640     11.299560     10.897380
# 25%       20.794760     18.912680     17.817150     17.379670     17.095670
# 50%       22.841770     21.582200     20.104590     19.223660     18.766630
# 75%       24.207410     22.445130     20.974610     19.947090     19.472260
# max       29.325650     31.602240     29.571860     30.163590     29.383740
#
#            redshift
# count  59445.000000
# mean       0.421596
# std        0.264858
# min       -0.009971
# 25%        0.164527
# 50%        0.456274
# 75%        0.594699
# max        1.995524

# %%
cOIDS_s.describe()
# Out:
#                   u             g             r             i             z  \
# count  21594.000000  21594.000000  21594.000000  21594.000000  21594.000000
# mean      20.689805     19.153188     18.946969     18.543736     17.870400
# std       68.228825     68.210460      1.972786      1.841714     68.193708
# min    -9999.000000  -9999.000000      9.822070      9.469903  -9999.000000
# 25%       19.327275     18.034847     17.454012     17.139703     16.963810
# 50%       21.010555     19.542825     18.955080     18.592360     18.319225
# 75%       22.960617     21.228690     20.557477     20.041690     19.729615
# max       30.660390     30.607000     29.374110     30.250090     26.427790
#
#            redshift
# count  21594.000000
# mean      -0.000115
# std        0.000465
# min       -0.004136
# 25%       -0.000295
# 50%       -0.000076
# 75%        0.000075
# max        0.004153

# %%
cOIDS_q.describe()
# Out:
#                   u             g             r             i             z  \
# count  18961.000000  18961.000000  18961.000000  18961.000000  18961.000000
# mean      21.547619     20.926193     20.624089     20.431173     20.266732
# std        1.495879      1.163239      1.084237      1.080135      1.095076
# min       10.996230     13.662170     12.357630     12.637440     11.302470
# 25%       20.637640     20.249730     20.006330     19.811070     19.644250
# 50%       21.503240     21.056290     20.772720     20.582110     20.373970
# 75%       22.286470     21.687770     21.413450     21.202280     21.001230
# max       32.781390     27.894820     27.397090     32.141470     28.790550
#
#            redshift
# count  18961.000000
# mean       1.719676
# std        0.913954
# min        0.000461
# 25%        1.106605
# 50%        1.617232
# 75%        2.220279
# max        7.011245
